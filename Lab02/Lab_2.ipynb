# %% [markdown]
# <a href="https://colab.research.google.com/github/bajon1/Deep-learning-lab/blob/main/Lab_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch torchvision matplotlib numpy

import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import time

device = "cuda" if torch.cuda.is_available() else "mps" if torch.backends.mps.is_available() else "cpu"
device
# Out:
# Requirement already satisfied: torch in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.12.0)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.27.0)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.4.3)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (65.5.0)
# Requirement already satisfied: sympy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torch) (2026.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: pip install --upgrade pip
# 'mps'

# %% [markdown]
# # Lab 2: PyTorch & Gradient Descent

# %% [markdown]
# ## Task 1: Implement a function that computes mean & std of a tensor and moves it to GPU if available.
#
# - Create tensors (zeros, ones, randn)
# - Math operations (+, *, @)
# - Reshape (reshape, view)
# - Difference between torch.tensor vs torch.as_tensor
# - CPU ↔ GPU transfer

# %%
torch.manual_seed(42)

# %%
zeros = torch.zeros(2, 3)
ones = torch.ones(2, 3)
randn = torch.randn(2, 3)

print(f"zeros: {zeros}")
print(f"ones: {ones}")
print(f"randn: {randn}")
# Out:
# zeros: tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# ones: tensor([[1., 1., 1.],
#         [1., 1., 1.]])
# randn: tensor([[ 0.3367,  0.1288,  0.2345],
#         [ 0.2303, -1.1229, -0.1863]])

# %%
zeros += 1
print(f"zeros: {zeros}")

zeros = torch.zeros(2, 3)
opz = 2*ones + zeros
print(f"two times ones plus zeros: {opz}")

multi = ones @ randn.T
print(f"matrix multiplication of ones and transposed randn: {multi}")
# Out:
# zeros: tensor([[1., 1., 1.],
#         [1., 1., 1.]])
# two times ones plus zeros: tensor([[2., 2., 2.],
#         [2., 2., 2.]])
# matrix multiplication of ones and transposed randn: tensor([[ 0.7000, -1.0789],
#         [ 0.7000, -1.0789]])

# %%
t1 = randn.reshape(1, 6)
print(f"reshape of continous tensor: {t1}")

t2 = randn.T.reshape(1, 6)
print(f"reshape of of transposed tensor: {t2}")

t3 = randn.view(1, 6)
print(f"view of continous tensor: {t3}")

# t4 = randn.T.view(1, 6) # error, viewed tensors must be continous
print(f"view of of transposed tensor: Error")
# Out:
# reshape of continous tensor: tensor([[ 0.3367,  0.1288,  0.2345,  0.2303, -1.1229, -0.1863]])
# reshape of of transposed tensor: tensor([[ 0.3367,  0.2303,  0.1288, -1.1229,  0.2345, -0.1863]])
# view of continous tensor: tensor([[ 0.3367,  0.1288,  0.2345,  0.2303, -1.1229, -0.1863]])
# view of of transposed tensor: Error

# %%
randn += 1

print(f"reshape/view check if it copy or view, if < 1 it's copy, if 1 > it's view : \nreshape of continous tensor: {t1}, \nreshape of of transposed tensor: {t2}, \nview of continous tensor: {t3}")

randn -= 1
# Out:
# reshape/view check if it copy or view, if < 1 it's copy, if 1 > it's view :
# reshape of continous tensor: tensor([[ 1.3367,  1.1288,  1.2345,  1.2303, -0.1229,  0.8137]]),
# reshape of of transposed tensor: tensor([[ 0.3367,  0.2303,  0.1288, -1.1229,  0.2345, -0.1863]]),
# view of continous tensor: tensor([[ 1.3367,  1.1288,  1.2345,  1.2303, -0.1229,  0.8137]])

# %%
arr = np.array([[1, 2], [3, 4], [5, 6]])

print(f"Numpy array: {arr}")

tensor = torch.tensor(arr)
nottensor = torch.as_tensor(arr)

print(f"Numpy to tensor copy: {tensor}")
print(f"Numpy to tensor view: {nottensor}")

arr += 1

print(f"Tensor after addition: {tensor}")
print(f"As_tensor after addition: {nottensor}")
# Out:
# Numpy array: [[1 2]
#  [3 4]
#  [5 6]]
# Numpy to tensor copy: tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# Numpy to tensor view: tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# Tensor after addition: tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# As_tensor after addition: tensor([[2, 3],
#         [4, 5],
#         [6, 7]])

# %%
print(f"Tensor device before change: {t1.device}")

device = torch.accelerator.current_accelerator() if torch.accelerator.is_available() else "cpu"
t1 = t1.to(device)

print(f"Tensor device after change: {t1.device}")
# Out:
# Tensor device before change: cpu
# Tensor device after change: mps:0

# %% [markdown]
# ## Task 2 – Manual Gradient Descent:
#
# - synthetic data y = 2x + 1 + noise,
# - predictions ŷ = b + w·x, MSE loss,
# - hand-computed gradients,
# - parameter update loop. Train for 1000 epochs and plot loss curve.

# %%
N = 100

x = torch.linspace(-1, 1, N)
noise = torch.randn(N) * 0.2

y = 2*x + 1 + noise

plt.scatter(x, y, s=30)
plt.plot(x, 2*x+1, color='r', label="y=2x+1")
plt.legend()
plt.show()

# %%
w = torch.rand(1) # start with random values
b = torch.rand(1)

y_hat = w*x + b

plt.scatter(x, y, s=30)
plt.plot(x, y_hat, color='r', label="y=2x+1")
plt.legend()
plt.show()

MSE = torch.mean((y_hat - y)**2)
true_MSE = torch.mean((2*x+1 - y)**2)

print(f"MSE: {MSE}")
print(f"True MSE: {true_MSE}")
# Out:
# MSE: 0.8115472197532654
# True MSE: 0.03419741988182068

# %%
loss = torch.mean((w*x + b - y)**2)
dw = torch.mean(2*(w*x + b - y)*x)
db = torch.mean(2*(w*x + b - y)*1)

# %%
epochs = 13000
lr = 3e-4

w = torch.rand(1)
b = torch.rand(1)

for epoch in range(epochs):
    loss = torch.mean((w*x + b - y)**2)
    dw   = torch.mean(2*(w*x + b - y)*x)
    db   = torch.mean(2*(w*x + b - y))

    w -= lr * dw
    b -= lr * db

    if epoch < 10 or epoch >= epochs - 10:
        print(f"Epoch {epoch}: Loss: {loss.item():.6f}")
    elif epoch == 10:
        print("...")
# Out:
# Epoch 0: Loss: 0.556724
# Epoch 1: Loss: 0.556410
# Epoch 2: Loss: 0.556097
# Epoch 3: Loss: 0.555784
# Epoch 4: Loss: 0.555471
# Epoch 5: Loss: 0.555158
# Epoch 6: Loss: 0.554846
# Epoch 7: Loss: 0.554533
# Epoch 8: Loss: 0.554221
# Epoch 9: Loss: 0.553909
# ...
# Epoch 12990: Loss: 0.035998
# Epoch 12991: Loss: 0.035997
# Epoch 12992: Loss: 0.035996
# Epoch 12993: Loss: 0.035995
# Epoch 12994: Loss: 0.035994
# Epoch 12995: Loss: 0.035994
# Epoch 12996: Loss: 0.035993
# Epoch 12997: Loss: 0.035992
# Epoch 12998: Loss: 0.035991
# Epoch 12999: Loss: 0.035990

# %%
y_hat = w*x + b

plt.scatter(x, y, s=30)
plt.plot(x, y_hat, color='r', label="y=2x+1")
plt.legend()
plt.show()

MSE = torch.mean((y_hat - y)**2)
true_MSE = torch.mean((2*x+1 - y)**2)

print(f"MSE: {MSE}")
print(f"True MSE: {true_MSE}")
# Out:
# MSE: 0.03598954528570175
# True MSE: 0.03419741988182068

# %% [markdown]
# # Task 3 – Autograd:
#
# - rewrite Task 2 using requires_grad=True and loss.backward()
# - update params inside torch.no_grad().
# - compare execution time and final parameter values vs manual implementation.

# %%
w = torch.rand(1, requires_grad=True) # start with random values
b = torch.rand(1, requires_grad=True)

y_hat = w*x + b

plt.scatter(x, y, s=30)
plt.plot(x, y_hat.detach().numpy(), color='r', label="y=2x+1")
plt.legend()
plt.show()

MSE = torch.mean((y_hat - y)**2)
true_MSE = torch.mean((2*x+1 - y)**2)

print(f"MSE: {MSE}")
print(f"True MSE: {true_MSE}")

epochs = 40000
lr = 3e-4

for epoch in range(epochs):
    loss = torch.mean((w*x + b - y)**2)

    if epoch < 10 or epoch >= epochs - 10:
        print(f"Epoch {epoch}: Loss: {loss.item():.6f}")
    elif epoch == 10:
        print("...")

    loss.backward()
    with torch.no_grad():
        w -= lr * w.grad
        b -= lr * b.grad
    w.grad.zero_()
    b.grad.zero_()

y_hat = w*x + b
MSE = torch.mean((y_hat - y)**2)

plt.scatter(x, y, s=30)
plt.plot(x, y_hat.detach().numpy(), color='r', label="y=2x+1")
plt.legend()
plt.show()

print(f"MSE: {MSE}")
print(f"True MSE: {true_MSE}")
# Out:
# MSE: 1.3314801454544067
# True MSE: 0.03419741988182068
# Epoch 0: Loss: 1.331480
# Epoch 1: Loss: 1.330929
# Epoch 2: Loss: 1.330378
# Epoch 3: Loss: 1.329827
# Epoch 4: Loss: 1.329277
# Epoch 5: Loss: 1.328726
# Epoch 6: Loss: 1.328176
# Epoch 7: Loss: 1.327627
# Epoch 8: Loss: 1.327077
# Epoch 9: Loss: 1.326528
# ...
# Epoch 39990: Loss: 0.034025
# Epoch 39991: Loss: 0.034025
# Epoch 39992: Loss: 0.034025
# Epoch 39993: Loss: 0.034025
# Epoch 39994: Loss: 0.034025
# Epoch 39995: Loss: 0.034025
# Epoch 39996: Loss: 0.034025
# Epoch 39997: Loss: 0.034025
# Epoch 39998: Loss: 0.034025
# Epoch 39999: Loss: 0.034025
# MSE: 0.034025032073259354
# True MSE: 0.03419741988182068

# %% [markdown]
# Autograd has lower efficiency because of gradient graph and internal implementation of autograd. When done by hand only calculations must be run which is faster and more epoch efficient.

# %% [markdown]
# Task 4 – nn.Module & nn.Linear:
# - build LinearRegression(nn.Module) with one nn.Linear layer
# - implement forward()
# - inspect parameters via state_dict(),
# - test with a forward pass.

# %%
N = 100

x = torch.linspace(-1, 1, N)
noise = torch.randn(N) * 0.2

y = 2*x + 1 + noise

x = x.view(N,1).to(device)
y = y.view(N,1).to(device)

print(x.shape, y.shape)
# Out:
# torch.Size([100, 1]) torch.Size([100, 1])

# %%
class LinearRegression(nn.Module):
  def __init__(self):
    super().__init__()
    self.linear = nn.Linear(1, 1)
  def forward(self, x):
    logits = self.linear(x)
    return logits

# %%
model = LinearRegression().to(device)
print(model.state_dict())
# Out:
# OrderedDict({'linear.weight': tensor([[-0.3208]], device='mps:0'), 'linear.bias': tensor([-0.7336], device='mps:0')})

# %%
y_hat = model(x)

plt.scatter(x.detach().cpu(), y.detach().cpu(), s=30, label="data")
plt.plot(x.detach().cpu(), y_hat.detach().cpu(), color='r', label="model (before training)")
plt.legend()
plt.show()
